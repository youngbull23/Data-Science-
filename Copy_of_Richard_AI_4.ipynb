# %% [markdown]
# <a href="https://colab.research.google.com/github/youngbull23/Data-Science-/blob/main/Copy_of_Richard_AI_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from skimage.io import imread

# %%
url = 'https://raw.githubusercontent.com/youngbull23/Probability_Statistics-Lab-1-Assignment-Danach-Richard/main/dataset/train/oregon%20ducks/fb.png'

# %%
im= imread(url)

# %%
plt.figure(figsize=(20,10))
plt.imshow(im);
plt.axis('off')
# Out:
# (-0.5, 467.5, 549.5, -0.5)

# %%
pot.imshow(in(;,;,0),cnap)

# %%
x = np.array([1,2,3,4])

# %%
np.sum(x) # equals 10

# %%
x.shape[0] # equals 4

# %%
np.sum(x)/x.shape[0] # 2.5

# %% [markdown]
# y=mx+b

# %% [markdown]
# Random Number Generator

# %%
m = 75                 # multiplier
b = 74                 # dividor 
n = 65537              # modulus

# %%
x = # 58

# %%
plt.plot(X[:100],'.')

# %%
plt.hist(X);

# %%
plt.hist(X,100);
